# %%
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %% [markdown]
# # 첫번째 의뢰작업

# %%
df = pd.read_excel('../data/원재료명 작업_빵류_3차.xlsx')
#df = pd.read_excel('../data/캔디_생산실적.xlsx')
#df
#df.to_pickle('../pkl/원재료명 작업_빵류_3차.pickle')

# %%
df = pd.read_pickle('../pkl/원재료명 작업_빵류_3차.pickle')
df
# Out:
#             인허가번호  보고년도     인허가일자     품목제조보고일      업체명(생산실적) 대표자명(생산실적)  \
# 0     19690231013  2021  19691226  19930903.0           동양식품        김영숙
# 1     19690449001  2021  19691008  20160721.0     광덕산호두과자전문점   최연심 외 1명
# 2     19690449001  2021  19691008  20160721.0     광덕산호두과자전문점   최연심 외 1명
# 3     19690449001  2021  19691008  20160721.0     광덕산호두과자전문점   최연심 외 1명
# 4     19710275003  2021  19711030  20200109.0          (주)샤니        이강섭
# ...           ...   ...       ...         ...            ...        ...
# 4327  20210372614  2021  20210825  20210903.0  (주)포비아워스 베이커리        박영진
# 4328  20210372614  2021  20210825  20210903.0  (주)포비아워스 베이커리        박영진
# 4329  20210372614  2021  20210825  20210903.0  (주)포비아워스 베이커리        박영진
# 4330  20210372614  2021  20210825  20210903.0  (주)포비아워스 베이커리        박영진
# 4331  20210372614  2021  20210825  20210903.0  (주)포비아워스 베이커리        박영진
#
#            업종       품목대장전산키           품목보고번호        품목보고번호_01  ...   71   72  \
# ...

# %%
df.iloc[:, 0:27].head()
# Out:
#          인허가번호  보고년도     인허가일자     품목제조보고일   업체명(생산실적) 대표자명(생산실적)       업종  \
# 0  19690231013  2021  19691226  19930903.0        동양식품        김영숙  식품제조가공업
# 1  19690449001  2021  19691008  20160721.0  광덕산호두과자전문점   최연심 외 1명  식품제조가공업
# 2  19690449001  2021  19691008  20160721.0  광덕산호두과자전문점   최연심 외 1명  식품제조가공업
# 3  19690449001  2021  19691008  20160721.0  광덕산호두과자전문점   최연심 외 1명  식품제조가공업
# 4  19710275003  2021  19711030  20200109.0       (주)샤니        이강섭  식품제조가공업
#
#         품목대장전산키           품목보고번호        품목보고번호_01  ... 국외판매금액(천원)  \
# 0  1.993021e+15     196902310135     196902310135  ...        0.0
# 1  2.016021e+15     196904490015     196904490015  ...        0.0
# 2  2.016021e+15     196904490016     196904490016  ...        0.0
# 3  2.016021e+15     196904490014     196904490014  ...        0.0
# 4  2.020021e+15  197102750034866  197102750034866  ...        0.0
#
#                                               원재료1레벨  품목_중  영양성분 code 유무  \
# ...

# %%
df['순서'].isnull().sum()
# Out:
# 4332

# %%
df.iloc[:, 0:25].isnull().sum()
# Out:
# 인허가번호              0
# 보고년도               0
# 인허가일자              0
# 품목제조보고일          197
# 업체명(생산실적)          0
# 대표자명(생산실적)         0
# 업종                 0
# 품목대장전산키          196
# 품목보고번호             0
# 품목보고번호_01          0
# 품목유형(생산실적)         0
# 제품명                0
# 생산량(KG)            0
# 생산액(천원)            0
# 국내판매량(KG)          0
# 국내판매금액(천원)         0
# 국외판매량(KG)          0
# 국외판매금액(천원)         0
# 원재료1레벨           197
# 품목_중               0
# 영양성분 code 유무       0
# 영양성분 code          0
# 원재료 작업             0
# N_원재료명             0
# 순서              4332
# dtype: int64

# %%
df.columns[0:25]
df['순서'].isnull().sum()
df['순서'].fillna('missing', inplace=True)
df['순서'].isnull().sum()
# Out:
# Index(['인허가번호', '보고년도', '인허가일자', '품목제조보고일', '업체명(생산실적)', '대표자명(생산실적)', '업종',
#        '품목대장전산키', '품목보고번호', '품목보고번호_01', '품목유형(생산실적)', '제품명', '생산량(KG)',
#        '생산액(천원)', '국내판매량(KG)', '국내판매금액(천원)', '국외판매량(KG)', '국외판매금액(천원)',
#        '원재료1레벨', '품목_중', '영양성분 code 유무', '영양성분 code', '원재료 작업', 'N_원재료명',
#        '순서'],
#       dtype='object')
# 4332
# 0

# %%
df.iloc[:, 0:25].head()
# Out:
#          인허가번호  보고년도     인허가일자     품목제조보고일   업체명(생산실적) 대표자명(생산실적)       업종  \
# 0  19690231013  2021  19691226  19930903.0        동양식품        김영숙  식품제조가공업
# 1  19690449001  2021  19691008  20160721.0  광덕산호두과자전문점   최연심 외 1명  식품제조가공업
# 2  19690449001  2021  19691008  20160721.0  광덕산호두과자전문점   최연심 외 1명  식품제조가공업
# 3  19690449001  2021  19691008  20160721.0  광덕산호두과자전문점   최연심 외 1명  식품제조가공업
# 4  19710275003  2021  19711030  20200109.0       (주)샤니        이강섭  식품제조가공업
#
#         품목대장전산키           품목보고번호        품목보고번호_01  ... 국내판매금액(천원) 국외판매량(KG)  \
# 0  1.993021e+15     196902310135     196902310135  ...    46866.0       0.0
# 1  2.016021e+15     196904490015     196904490015  ...   203820.0       0.0
# 2  2.016021e+15     196904490016     196904490016  ...   189100.0       0.0
# 3  2.016021e+15     196904490014     196904490014  ...   130010.0       0.0
# 4  2.020021e+15  197102750034866  197102750034866  ...        0.0       0.0
#
# ...

# %%
data = df.head(1)
data
# Out:
#          인허가번호  보고년도     인허가일자     품목제조보고일 업체명(생산실적) 대표자명(생산실적)       업종  \
# 0  19690231013  2021  19691226  19930903.0      동양식품        김영숙  식품제조가공업
#
#         품목대장전산키        품목보고번호     품목보고번호_01  ...   71   72   73   74   75  \
# 0  1.993021e+15  196902310135  196902310135  ...  NaN  NaN  NaN  NaN  NaN
#
#     76   77   78  79  80
# 0  NaN  NaN  NaN NaN NaN
#
# [1 rows x 105 columns]

# %%
data.columns[0:25]
data.iloc[:, 24:50]
# Out:
# Index(['인허가번호', '보고년도', '인허가일자', '품목제조보고일', '업체명(생산실적)', '대표자명(생산실적)', '업종',
#        '품목대장전산키', '품목보고번호', '품목보고번호_01', '품목유형(생산실적)', '제품명', '생산량(KG)',
#        '생산액(천원)', '국내판매량(KG)', '국내판매금액(천원)', '국외판매량(KG)', '국외판매금액(천원)',
#        '원재료1레벨', '품목_중', '영양성분 code 유무', '영양성분 code', '원재료 작업', 'N_원재료명',
#        '순서'],
#       dtype='object')
#         순서        1        2        3               4   5     6    7        8  \
# 0  missing  밀가루(34)  식용유(22)  백설탕(17)  강낭콩앙금(12)[흰강낭콩  물엿  정제소금  백설탕  소르빈산칼륨]
#
#          9  ...             16               17               18          19  \
# 0  물엿(7.5)  ...  탄산수소나트륨(0.01)  식품첨가물혼합제제(0.01)  식품첨가물혼합제제(0.01)  정제소금(0.01)
#
#     20   21   22   23   24   25
# 0  NaN  NaN  NaN  NaN  NaN  NaN
#
# [1 rows x 26 columns]

# %%
tf = data.melt(id_vars= data.columns[0:25], var_name="순서", value_name="원재료").dropna()
tf
# Out:
#           인허가번호  보고년도     인허가일자     품목제조보고일 업체명(생산실적) 대표자명(생산실적)       업종  \
# 0   19690231013  2021  19691226  19930903.0      동양식품        김영숙  식품제조가공업
# 1   19690231013  2021  19691226  19930903.0      동양식품        김영숙  식품제조가공업
# 2   19690231013  2021  19691226  19930903.0      동양식품        김영숙  식품제조가공업
# 3   19690231013  2021  19691226  19930903.0      동양식품        김영숙  식품제조가공업
# 4   19690231013  2021  19691226  19930903.0      동양식품        김영숙  식품제조가공업
# 5   19690231013  2021  19691226  19930903.0      동양식품        김영숙  식품제조가공업
# 6   19690231013  2021  19691226  19930903.0      동양식품        김영숙  식품제조가공업
# 7   19690231013  2021  19691226  19930903.0      동양식품        김영숙  식품제조가공업
# 8   19690231013  2021  19691226  19930903.0      동양식품        김영숙  식품제조가공업
# 9   19690231013  2021  19691226  19930903.0      동양식품        김영숙  식품제조가공업
# 10  19690231013  2021  19691226  19930903.0      동양식품        김영숙  식품제조가공업
# 11  19690231013  2021  19691226  19930903.0      동양식품        김영숙  식품제조가공업
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
from tqdm import tqdm

for i in tqdm(range(1, len(df))) : #range(len(df)):
    tf = tf.append(df[(i+0):(i+1)].melt(id_vars= data.columns[0:25], var_name="순서", value_name="원재료").dropna())
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 4331/4331 [01:34<00:00, 45.88it/s]

# %%
tf.to_excel('../data/원재료명 작업_빵류_3차_logntype.xlsx')

# %% [markdown]
# # 두번째 의뢰작업

# %%
#file ='20220926_20220922_영양기능연구과_안정선_과자  빵류  초콜릿류  시리얼류_생산실적_하위원재료표시_2차 원재료명 작업.xlsx'
df = pd.read_excel('../data/원재료명 작업_캔디류_3차.xlsx')

# %%
#df.to_pickle('../pkl/원재료명 작업_캔디류_3차.pickle')
#df = pd.read_pickle('../pkl/원재료명 작업_캔디류_3차.pickle')
df
# Out:
#            인허가번호  보고년도     인허가일자   품목제조보고일         업체명(생산실적) 대표자명(생산실적)  \
# 0    19660144002  2021  19660430  20001208              국제제과        유동호
# 1    19660144002  2021  19660430  20060518              국제제과        유동호
# 2    19660144002  2021  19660430  20190905              국제제과        유동호
# 3    19660144002  2021  19660430  20200723              국제제과        유동호
# 4    19660144002  2021  19660430  20030529              국제제과        유동호
# ..           ...   ...       ...       ...               ...        ...
# 377  20190066477  2021  20190529  20190617               마켓랩        김현우
# 378  20190066477  2021  20190529  20190617               마켓랩        김현우
# 379  20190066477  2021  20190529  20190617               마켓랩        김현우
# 380  20190559114  2021  20190416  20210119  농업회사법인 주식회사 내츄럴엔   정수연 외 1명
# 381  20190559114  2021  20190416  20190618  농업회사법인 주식회사 내츄럴엔   정수연 외 1명
#
#           업종           품목대장전산키          품목보고번호       품목보고번호_01  ...   57   58  \
# ...

# %%
df.columns[0:25]
# Out:
# Index(['인허가번호', '보고년도', '인허가일자', '품목제조보고일', '업체명(생산실적)', '대표자명(생산실적)', '업종',
#        '품목대장전산키', '품목보고번호', '품목보고번호_01', '품목유형(생산실적)', '제품명', '생산량(KG)',
#        '생산액(천원)', '국내판매량(KG)', '국내판매금액(천원)', '국외판매량(KG)', '국외판매금액(천원)',
#        '원재료1레벨', '품목_중', '영양성분 code 유무', '영양성분 code', '원재료 작업', 'N_원재료명',
#        '순서'],
#       dtype='object')

# %% [markdown]
# ### Step 3. 첫 줄을 변화하여 보기
# - df.head(1) : 1번쨰 데이터만 보여라, 이것을 data에 저장하라는 의미
# - 25번째 가지 컬럼은 유지하고 나머지는 녹여서 아래로 붙여라
# ### 한글명 컬럼이 있는 순번은 어디인지 확인

# %%
df.iloc[:, 0:25].head(2)
# Out:
#          인허가번호  보고년도     인허가일자   품목제조보고일 업체명(생산실적) 대표자명(생산실적)       업종  \
# 0  19660144002  2021  19660430  20001208      국제제과        유동호  식품제조가공업
# 1  19660144002  2021  19660430  20060518      국제제과        유동호  식품제조가공업
#
#             품목대장전산키         품목보고번호      품목보고번호_01  ... 국내판매금액(천원) 국외판매량(KG)  \
# 0  2000021004042972  1966014400220  1966014400220  ...   217782.0       0.0
# 1  2006021003058127  1966014400269  1966014400269  ...   159380.0       0.0
#
#    국외판매금액(천원)                                             원재료1레벨  품목_중  \
# 0         0.0  물엿(49.155),백설탕(30),야자경화유(3),연유(14.4),전지분유(2.08...    캔디
# 1         0.0  물엿(59.75),땅콩(8.5),땅콩버터(8.5),전지분유(0.85),식품첨가물,정...    캔디
#
#    영양성분 code 유무            영양성분 code  원재료 작업 N_원재료명  순서
# 0             Y  P101-031000200-2191   3차 대상     12 NaN
# 1             Y  P101-031000200-2194   3차 대상     13 NaN
#
# [2 rows x 25 columns]

# %%
df['순서'].isnull().sum()
df['순서'].fillna('missing', inplace=True)
df['순서'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ##  ['원재료 작업 여부']컬럼에 NANㅇ 있기때문에 melt 명령어에서 dropna()하면 모두 사라지니 fillna('missing')하고 진행

# %%
df[df.columns[0:25]].isnull().sum()
# Out:
# 인허가번호           0
# 보고년도            0
# 인허가일자           0
# 품목제조보고일         0
# 업체명(생산실적)       0
# 대표자명(생산실적)      0
# 업종              0
# 품목대장전산키         0
# 품목보고번호          0
# 품목보고번호_01       0
# 품목유형(생산실적)      0
# 제품명             0
# 생산량(KG)         0
# 생산액(천원)         0
# 국내판매량(KG)       0
# 국내판매금액(천원)      0
# 국외판매량(KG)       0
# 국외판매금액(천원)      0
# 원재료1레벨          0
# 품목_중            0
# 영양성분 code 유무    0
# 영양성분 code       0
# 원재료 작업          0
# N_원재료명          0
# 순서              0
# dtype: int64

# %%
data = df.head(1)
data
# Out:
#          인허가번호  보고년도     인허가일자   품목제조보고일 업체명(생산실적) 대표자명(생산실적)       업종  \
# 0  19660144002  2021  19660430  20001208      국제제과        유동호  식품제조가공업
#
#             품목대장전산키         품목보고번호      품목보고번호_01  ...   57   58   59   60  \
# 0  2000021004042972  1966014400220  1966014400220  ...  NaN  NaN  NaN  NaN
#
#     61   62   63   64   65   66
# 0  NaN  NaN  NaN  NaN  NaN  NaN
#
# [1 rows x 91 columns]

# %%
tf = data.melt(id_vars= data.columns[0:25], var_name="순서", value_name="원재료").dropna()
tf
# Out:
#           인허가번호  보고년도     인허가일자   품목제조보고일 업체명(생산실적) 대표자명(생산실적)       업종  \
# 0   19660144002  2021  19660430  20001208      국제제과        유동호  식품제조가공업
# 1   19660144002  2021  19660430  20001208      국제제과        유동호  식품제조가공업
# 2   19660144002  2021  19660430  20001208      국제제과        유동호  식품제조가공업
# 3   19660144002  2021  19660430  20001208      국제제과        유동호  식품제조가공업
# 4   19660144002  2021  19660430  20001208      국제제과        유동호  식품제조가공업
# 5   19660144002  2021  19660430  20001208      국제제과        유동호  식품제조가공업
# 6   19660144002  2021  19660430  20001208      국제제과        유동호  식품제조가공업
# 7   19660144002  2021  19660430  20001208      국제제과        유동호  식품제조가공업
# 8   19660144002  2021  19660430  20001208      국제제과        유동호  식품제조가공업
# 9   19660144002  2021  19660430  20001208      국제제과        유동호  식품제조가공업
# 10  19660144002  2021  19660430  20001208      국제제과        유동호  식품제조가공업
# 11  19660144002  2021  19660430  20001208      국제제과        유동호  식품제조가공업
#
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
from tqdm import tqdm

for i in tqdm(range(1, len(df))) : #range(len(df)):
    tf = tf.append(df[(i+0):(i+1)].melt(id_vars= data.columns[0:25], var_name="순서", value_name="원재료").dropna())
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 381/381 [00:06<00:00, 56.02it/s]

# %%
tf.to_excel('../data/기호식품 원재료명 정리_2차_logntype.xlsx')

# %%
tf
# Out:
#           인허가번호  보고년도     인허가일자     품목제조보고일  업체명(생산실적) 대표자명(생산실적)       업종  \
# 0   19690086003  2021  19690307  20200114.0    롯데제과(주)        이영구  식품제조가공업
# 1   19690086003  2021  19690307  20200114.0    롯데제과(주)        이영구  식품제조가공업
# 2   19690086003  2021  19690307  20200114.0    롯데제과(주)        이영구  식품제조가공업
# 3   19690086003  2021  19690307  20200114.0    롯데제과(주)        이영구  식품제조가공업
# 4   19690086003  2021  19690307  20200114.0    롯데제과(주)        이영구  식품제조가공업
# ..          ...   ...       ...         ...        ...        ...      ...
# 4   20160080733  2021  20160722  20210114.0  (주)카카오브라운        정영택  식품제조가공업
# 5   20160080733  2021  20160722  20210114.0  (주)카카오브라운        정영택  식품제조가공업
# 6   20160080733  2021  20160722  20210114.0  (주)카카오브라운        정영택  식품제조가공업
# 7   20160080733  2021  20160722  20210114.0  (주)카카오브라운        정영택  식품제조가공업
# 8   20160080733  2021  20160722  20210114.0  (주)카카오브라운        정영택  식품제조가공업
#
# ...

# %%
tf
# Out:
#           인허가번호  보고년도     인허가일자   품목제조보고일         업체명(생산실적) 대표자명(생산실적)  \
# 0   19660144002  2021  19660430  20001208              국제제과        유동호
# 1   19660144002  2021  19660430  20001208              국제제과        유동호
# 2   19660144002  2021  19660430  20001208              국제제과        유동호
# 3   19660144002  2021  19660430  20001208              국제제과        유동호
# 4   19660144002  2021  19660430  20001208              국제제과        유동호
# ..          ...   ...       ...       ...               ...        ...
# 13  20190559114  2021  20190416  20210119  농업회사법인 주식회사 내츄럴엔   정수연 외 1명
# 14  20190559114  2021  20190416  20210119  농업회사법인 주식회사 내츄럴엔   정수연 외 1명
# 15  20190559114  2021  20190416  20210119  농업회사법인 주식회사 내츄럴엔   정수연 외 1명
# 16  20190559114  2021  20190416  20210119  농업회사법인 주식회사 내츄럴엔   정수연 외 1명
# 0   20190559114  2021  20190416  20190618  농업회사법인 주식회사 내츄럴엔   정수연 외 1명
#
#          업종           품목대장전산키         품목보고번호      품목보고번호_01  ... 국외판매금액(천원)  \
# ...

# %%
tf.to_excel('../data/원재료명 작업_캔디류_3차_logntype.xlsx')

# %%
# End
